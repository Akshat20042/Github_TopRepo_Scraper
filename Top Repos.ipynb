# %% [markdown]
# ## Pick a website and describe your objective
#
# - Browse through different sites and pick on to scrape. Check the "Project Ideas" section for inspiration.
# - Identify the information you'd like to scrape from the site. Decide the format of the output CSV file.
# - Summarize your project idea and outline your strategy in a Juptyer notebook. Use the "New" button above.

# %% [markdown]
# ### Outline
#
# - We're going to scrape https://github.com/topics
# - We'll get a list of topics, topic title, topic url, and topic description
# - For each topic we'll get top 25 repos in the topic from the topic page
# - For each repo we have repo name,stars, username, url
# - for each topic a csv file will be made in the format:
# -

# %% [markdown]
# ## Use the requests library to download web pages
#
# - Inspect the website's HTML source and identify the right URLs to download.
# - Download and save web pages locally using the requests library.
# - Create a function to automate downloading for different topics/search queries.

# %%
# !pip install requests --upgrade --quiet

# %%
import requests

# %%
topics_url = 'https://github.com/topics'

# %%
response = requests.get(topics_url)

# %%
response.status_code
# Out:
# 200

# %%
len(response.text)
# Out:
# 205543

# %%
top_lines = response.text[:100000]

# %%
page_content = response.text

# %%
with open('webpage.html', 'w') as f:
          f.write(top_lines)

# %% [markdown]
# ## Use Beautiful Soup to parse and extract information
#
# - Parse and explore the structure of downloaded web pages using Beautiful soup.
# - Use the right properties and methods to extract the required information.
# - Create functions to extract from the page into lists and dictionaries.
# - (Optional) Use a REST API to acquire additional information if required.

# %%
# !pip install beautifulsoup4 --upgrade --quiet

# %%
from bs4 import BeautifulSoup

# %%
doc = BeautifulSoup(page_content, 'html.parser')

# %%
selection_class = 'f3 lh-condensed mb-0 mt-1 Link--primary'

title_p_tags = doc.find_all('p',{'class':selection_class})

# %%
len(title_p_tags)
# Out:
# 30

# %%
title_p_tags[:5]
# Out:
# [<p class="f3 lh-condensed mb-0 mt-1 Link--primary">3D</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Ajax</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Algorithm</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Amp</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Android</p>]

# %%
ss_class = 'f5 color-fg-muted mb-0 mt-1'

desc_p_tags = doc.find_all('p',{'class':ss_class})

# %%
len(desc_p_tags)
# Out:
# 30

# %%
desc_p_tags[:5]
# Out:
# [<p class="f5 color-fg-muted mb-0 mt-1">
#            3D refers to the use of three-dimensional graphics, modeling, and animation in various industries.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Ajax is a technique for creating interactive web applications.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Algorithms are self-contained sequences that carry out a variety of tasks.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Amp is a non-blocking concurrency library for PHP.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Android is an operating system built by Google designed for mobile devices.
#          </p>]

# %%
topic_url_tags = doc.find_all('a',{'class':'no-underline flex-grow-0'})

# %%
len(topic_url_tags)
# Out:
# 30

# %%
topic_url_tags[5]['href']
# Out:
# '/topics/angular'

# %%
topic_titles = []
topic_desc = []

for tag in title_p_tags:
    topic_titles.append(tag.text)
for desc in desc_p_tags:
    topic_desc.append(desc.text.strip())

# %%
topic_urls = []
base_url = 'https://github.com'

for tag in topic_url_tags:
    topic_urls.append(base_url + tag['href'])

# %%
topic_urls[:2]
# Out:
# ['https://github.com/topics/3d', 'https://github.com/topics/ajax']

# %%
topic_desc[:2]
# Out:
# ['3D refers to the use of three-dimensional graphics, modeling, and animation in various industries.',
#  'Ajax is a technique for creating interactive web applications.']

# %%
# !pip install pandas --upgrade --quiet

# %%
import pandas as pd

# %%
topics_dict = {
    'title':topic_titles,
    'description':topic_desc,
    'utl':topic_urls
}

# %%
topics_df = pd.DataFrame(topics_dict)

# %%
topics_df
# Out:
#                      title                                        description  \
# 0                       3D  3D refers to the use of three-dimensional grap...
# 1                     Ajax  Ajax is a technique for creating interactive w...
# 2                Algorithm  Algorithms are self-contained sequences that c...
# 3                      Amp  Amp is a non-blocking concurrency library for ...
# 4                  Android  Android is an operating system built by Google...
# 5                  Angular  Angular is an open source web application plat...
# 6                  Ansible  Ansible is a simple and powerful automation en...
# 7                      API  An API (Application Programming Interface) is ...
# 8                  Arduino  Arduino is an open source platform for buildin...
# 9                  ASP.NET  ASP.NET is a web framework for building modern...
# 10           Awesome Lists  An awesome list is a list of awesome things cu...
# 11     Amazon Web Services  Amazon Web Services provides on-demand cloud c...
# 12                   Azure  Azure is a cloud computing service created by ...
# 13                   Babel  Babel is a compiler for writing next generatio...
# 14                    Bash  Bash is a shell and command language interpret...
# 15                 Bitcoin  Bitcoin is a cryptocurrency developed by Satos...
# 16               Bootstrap  Bootstrap is an HTML, CSS, and JavaScript fram...
# 17                     Bot  A bot is an application that runs automated ta...
# 18                       C  C is a general purpose programming language th...
# 19                  Chrome  Chrome is a web browser from the tech company ...
# 20        Chrome extension  Chrome extensions enable users to customize th...
# 21  Command-line interface  A CLI, or command-line interface, is a console...
# 22                 Clojure  Clojure is a dynamic, general-purpose programm...
# 23            Code quality  Automate your code review with style, quality,...
# 24             Code review  Ensure your code meets quality standards and s...
# 25                Compiler  Compilers are software that translate higher-l...
# 26  Continuous integration  Automatically build and test your code as you ...
# 27                     C++  C++ is a general purpose and object-oriented p...
# 28          Cryptocurrency  A cryptocurrency is a digital currency that us...
# 29                 Crystal  Crystal is a self-hosted, general purpose prog...
#
#                                                  utl
# 0                       https://github.com/topics/3d
# 1                     https://github.com/topics/ajax
# 2                https://github.com/topics/algorithm
# 3                    https://github.com/topics/amphp
# 4                  https://github.com/topics/android
# 5                  https://github.com/topics/angular
# 6                  https://github.com/topics/ansible
# 7                      https://github.com/topics/api
# 8                  https://github.com/topics/arduino
# 9                   https://github.com/topics/aspnet
# 10                 https://github.com/topics/awesome
# 11                     https://github.com/topics/aws
# 12                   https://github.com/topics/azure
# 13                   https://github.com/topics/babel
# 14                    https://github.com/topics/bash
# 15                 https://github.com/topics/bitcoin
# 16               https://github.com/topics/bootstrap
# 17                     https://github.com/topics/bot
# 18                       https://github.com/topics/c
# 19                  https://github.com/topics/chrome
# 20        https://github.com/topics/chrome-extension
# 21                     https://github.com/topics/cli
# 22                 https://github.com/topics/clojure
# 23            https://github.com/topics/code-quality
# 24             https://github.com/topics/code-review
# 25                https://github.com/topics/compiler
# 26  https://github.com/topics/continuous-integration
# 27                     https://github.com/topics/cpp
# 28          https://github.com/topics/cryptocurrency
# 29                 https://github.com/topics/crystal

# %% [markdown]
# ## Create CSV file(s) with the extracted information

# %%
topics_df.to_csv('topics.csv',index = None)

# %% [markdown]
# ## Getting info out of a topic page

# %%
topic_page_url = topic_urls[0]

# %%
topic_page_url
# Out:
# 'https://github.com/topics/3d'

# %%
response = requests.get(topic_page_url)

# %%
response.status_code
# Out:
# 200

# %%
len(response.text)
# Out:
# 520248

# %%
topic_doc = BeautifulSoup(response.text,'html.parser')

# %%
repo_tags = topic_doc.find_all('h3',{'class':'f3 color-fg-muted text-normal lh-condensed'})

# %%
len(repo_tags)
# Out:
# 20

# %%
a_tags = repo_tags[0].find_all('a')

# %%
a_tags[0].text.strip()
# Out:
# 'mrdoob'

# %%
star_tags = topic_doc.find_all('span',{'class':'Counter js-social-count'})

# %%
len(star_tags)
# Out:
# 20

# %%
star_tags[0].text.strip()
# Out:
# '104k'

# %%
def parse_star_count(stars_cnt):
    stars_cnt = stars_cnt.strip()
    if(stars_cnt[-1] == 'k'):
        return int(float(stars_cnt[:-1])*1000)
    else:
        return int(stars_cnt)

# %%
parse_star_count(star_tags[0].text)
# Out:
# 104000

# %%
def get_repo_info(h3_tag, star_tag):
    #returns all the req info about the repo
    a_tags = h3_tag.find_all('a')
    username = a_tags[0].text.strip()
    repo_name = a_tags[1].text.strip()
    repo_url = base_url + a_tags[1]['href']
    stars = parse_star_count(star_tag.text.strip())
    return username, repo_name, repo_url, stars

# %%
get_repo_info(repo_tags[0],star_tags[0])
# Out:
# ('mrdoob', 'three.js', 'https://github.com/mrdoob/three.js', 104000)

# %%
info_repo = {
    'username' : [],
    'repo_name' : [],
    'repo_url' : [],
    'stars' : [],
}
for i in range(len(repo_tags)):
    repo_info = (get_repo_info(repo_tags[i],star_tags[i]))
    info_repo['username'].append(repo_info[0])
    info_repo['repo_name'].append(repo_info[1])
    info_repo['repo_url'].append(repo_info[2])
    info_repo['stars'].append(repo_info[3])

# %%
info_repo_df = pd.DataFrame(info_repo)

# %%
info_repo_df.to_csv("Repo_Info.csv",index = None)

# %%
info_repo_df
# Out:
#               username                      repo_name  \
# 0               mrdoob                       three.js
# 1               pmndrs              react-three-fiber
# 2               libgdx                         libgdx
# 3            BabylonJS                     Babylon.js
# 4              FreeCAD                        FreeCAD
# 5                ssloy                   tinyrenderer
# 6              lettier  3d-game-shaders-for-beginners
# 7             aframevr                         aframe
# 8              blender                        blender
# 9             CesiumGS                         cesium
# 10                4ian                       GDevelop
# 11             isl-org                         Open3D
# 12            MonoGame                       MonoGame
# 13              mapbox                   mapbox-gl-js
# 14           metafizzy                           zdog
# 15         timzhang642            3D-Machine-Learning
# 16  nerfstudio-project                     nerfstudio
# 17               cocos                   cocos-engine
# 18             domlysz                     BlenderGIS
# 19         FyroxEngine                          Fyrox
#
#                                              repo_url   stars
# 0                  https://github.com/mrdoob/three.js  104000
# 1         https://github.com/pmndrs/react-three-fiber   28000
# 2                    https://github.com/libgdx/libgdx   23600
# 3             https://github.com/BabylonJS/Babylon.js   23500
# 4                  https://github.com/FreeCAD/FreeCAD   22700
# 5               https://github.com/ssloy/tinyrenderer   21100
# 6   https://github.com/lettier/3d-game-shaders-for...   18300
# 7                  https://github.com/aframevr/aframe   16800
# 8                  https://github.com/blender/blender   13900
# 9                  https://github.com/CesiumGS/cesium   13200
# 10                   https://github.com/4ian/GDevelop   12500
# 11                  https://github.com/isl-org/Open3D   11800
# 12               https://github.com/MonoGame/MonoGame   11700
# 13             https://github.com/mapbox/mapbox-gl-js   11400
# 14                  https://github.com/metafizzy/zdog   10400
# 15  https://github.com/timzhang642/3D-Machine-Lear...    9800
# 16   https://github.com/nerfstudio-project/nerfstudio    9800
# 17              https://github.com/cocos/cocos-engine    8300
# 18              https://github.com/domlysz/BlenderGIS    8000
# 19               https://github.com/FyroxEngine/Fyrox    7900

# %%
import os

def get_topic_page(topic_url):
    #Download the page
    response = requests.get(topic_url)
    #check response code
    if response.status_code != 200:
        raise Exception("Failed to load page {}".format(topic_url))
    #Parse using beautifulsoup
    topic_doc = BeautifulSoup(response.text,'html.parser')
    return topic_doc

def get_repo_info(h3_tag, star_tag):
    #returns all the req info about the repo
    a_tags = h3_tag.find_all('a')
    username = a_tags[0].text.strip()
    repo_name = a_tags[1].text.strip()
    repo_url = base_url + a_tags[1]['href']
    stars = parse_star_count(star_tag.text.strip())
    return username, repo_name, repo_url, stars

def get_topic_repos(topic_doc):
    
    
    repo_tags = topic_doc.find_all('h3',{'class':'f3 color-fg-muted text-normal lh-condensed'})
    #get the number of stars
    star_tags = topic_doc.find_all('span',{'class':'Counter js-social-count'})

    info_repo = {
        'username' : [],
        'repo_name' : [],
        'repo_url' : [],
        'stars' : [],
    }
    #get repo info
    for i in range(len(repo_tags)):
        repo_info = (get_repo_info(repo_tags[i],star_tags[i]))
        info_repo['username'].append(repo_info[0])
        info_repo['repo_name'].append(repo_info[1])
        info_repo['repo_url'].append(repo_info[2])
        info_repo['stars'].append(repo_info[3])
    return pd.DataFrame(info_repo,index=None)

def scrape_topic(topic_url,topic_name):
    fname = topic_name + '.csv'
    if os.path.exists(fname):
        print("The file {} already exists".format(fname))
        return
    topic_df = get_topic_repos(get_topic_page(topic_url))
    topic_df.to_csv(fname, index = None)

# %%
url4 = topic_urls[4]

# %%
topic_4_doc = get_topic_page(url4)

# %%
topic4_repos = get_topic_repos(topic_4_doc)

# %%
topic4_repos
# Out:
#             username                     repo_name  \
# 0            flutter                       flutter
# 1           facebook                  react-native
# 2         Genymobile                        scrcpy
# 3          justjavac  free-programming-books-zh_CN
# 4   Hack-with-Github               Awesome-Hacking
# 5             Solido               awesome-flutter
# 6         tldr-pages                          tldr
# 7           wasabeef            awesome-android-ui
# 8             google         material-design-icons
# 9          laurent22                        joplin
# 10          appwrite                      appwrite
# 11            square                        okhttp
# 12           android          architecture-samples
# 13            square                      retrofit
# 14            skylot                          jadx
# 15          dcloudio                       uni-app
# 16          fastlane                      fastlane
# 17            termux                    termux-app
# 18             2dust                       v2rayNG
# 19           PhilJay                MPAndroidChart
#
#                                              repo_url   stars
# 0                  https://github.com/flutter/flutter  168000
# 1            https://github.com/facebook/react-native  120000
# 2                https://github.com/Genymobile/scrcpy  117000
# 3   https://github.com/justjavac/free-programming-...  112000
# 4   https://github.com/Hack-with-Github/Awesome-Ha...   88000
# 5           https://github.com/Solido/awesome-flutter   54500
# 6                  https://github.com/tldr-pages/tldr   53200
# 7      https://github.com/wasabeef/awesome-android-ui   51300
# 8     https://github.com/google/material-design-icons   51000
# 9                 https://github.com/laurent22/joplin   47400
# 10               https://github.com/appwrite/appwrite   46600
# 11                   https://github.com/square/okhttp   46100
# 12    https://github.com/android/architecture-samples   44700
# 13                 https://github.com/square/retrofit   43200
# 14                     https://github.com/skylot/jadx   42600
# 15                https://github.com/dcloudio/uni-app   40400
# 16               https://github.com/fastlane/fastlane   39800
# 17               https://github.com/termux/termux-app   38300
# 18                   https://github.com/2dust/v2rayNG   37900
# 19          https://github.com/PhilJay/MPAndroidChart   37700

# %%
get_topic_repos(get_topic_page(topic_urls[5]))
# Out:
#          username                          repo_name  \
# 0       justjavac       free-programming-books-zh_CN
# 1         angular                            angular
# 2     storybookjs                          storybook
# 3     leonardomso                     33-js-concepts
# 4      ionic-team                    ionic-framework
# 5        prettier                           prettier
# 6        Asabeneh              30-Days-Of-JavaScript
# 7         SheetJS                            sheetjs
# 8         angular                        angular-cli
# 9        wailsapp                              wails
# 10       sudheerj     javascript-interview-questions
# 11        angular                         components
# 12   NativeScript                       NativeScript
# 13           nrwl                                 nx
# 14   goldbergyoni  javascript-testing-best-practices
# 15  paperless-ngx                      paperless-ngx
# 16         pubkey                               rxdb
# 17       jhipster                 generator-jhipster
# 18        teambit                                bit
# 19    sweetalert2                        sweetalert2
#
#                                              repo_url   stars
# 0   https://github.com/justjavac/free-programming-...  112000
# 1                  https://github.com/angular/angular   96700
# 2            https://github.com/storybookjs/storybook   85200
# 3       https://github.com/leonardomso/33-js-concepts   64500
# 4       https://github.com/ionic-team/ionic-framework   51300
# 5                https://github.com/prettier/prettier   49800
# 6   https://github.com/Asabeneh/30-Days-Of-JavaScript   43800
# 7                  https://github.com/SheetJS/sheetjs   35300
# 8              https://github.com/angular/angular-cli   26800
# 9                   https://github.com/wailsapp/wails   26500
# 10  https://github.com/sudheerj/javascript-intervi...   24800
# 11              https://github.com/angular/components   24500
# 12       https://github.com/NativeScript/NativeScript   24500
# 13                         https://github.com/nrwl/nx   24300
# 14  https://github.com/goldbergyoni/javascript-tes...   24200
# 15     https://github.com/paperless-ngx/paperless-ngx   24000
# 16                     https://github.com/pubkey/rxdb   21900
# 17     https://github.com/jhipster/generator-jhipster   21700
# 18                     https://github.com/teambit/bit   18000
# 19         https://github.com/sweetalert2/sweetalert2   17500

# %% [markdown]
# ## Scaling this code

# %% [markdown]
# Write single function to :
# 1. Get the list of topics from the topic page
# 2. Get the list of top repos from the individual topic pages
# 3. For each topic, create a csv of the top repos of the topic

# %%
topics_url
# Out:
# 'https://github.com/topics'

# %%
def get_topic_title(doc):
    
    title_p_tags = doc.find_all('p',{'class':'f3 lh-condensed mb-0 mt-1 Link--primary'})
    topic_titles = []
    for tag in title_p_tags:
        topic_titles.append(tag.text.strip())
    return topic_titles

def get_topic_desc(doc):
    desc_p_tags = doc.find_all('p',{'class':'f5 color-fg-muted mb-0 mt-1'})
    topic_desc = []
    for desc in desc_p_tags:
        topic_desc.append(desc.text.strip())
    return topic_desc

def get_repo_info(h3_tag, star_tag):
    #returns all the req info about the repo
    a_tags = h3_tag.find_all('a')
    username = a_tags[0].text.strip()
    repo_name = a_tags[1].text.strip()
    repo_url = base_url + a_tags[1]['href']
    stars = parse_star_count(star_tag.text.strip())
    return username, repo_name, repo_url, stars

def get_topic_urls(doc):
    
    topic_url_tags = doc.find_all('a',{'class':'no-underline flex-grow-0'})
    topic_urls = []
    base_url = 'https://github.com'
    
    for tag in topic_url_tags:
        topic_urls.append(base_url + tag['href'])

    return topic_urls


def scrape_topics():
    topics_url = 'https://github.com/topics'
    response = requests.get(topics_url)
    if response.status_code != 200:
        raise Exception("Failed to load page {}".format(topics_url))
        
    topics_dict ={
        'titles': get_topic_title(doc),
        'descs': get_topic_desc(doc),
        'url': get_topic_urls(doc)
    }
    return pd.DataFrame(topics_dict)

# %%
scrape_topics()
# Out:
#                     titles                                              descs  \
# 0                       3D  3D refers to the use of three-dimensional grap...
# 1                     Ajax  Ajax is a technique for creating interactive w...
# 2                Algorithm  Algorithms are self-contained sequences that c...
# 3                      Amp  Amp is a non-blocking concurrency library for ...
# 4                  Android  Android is an operating system built by Google...
# 5                  Angular  Angular is an open source web application plat...
# 6                  Ansible  Ansible is a simple and powerful automation en...
# 7                      API  An API (Application Programming Interface) is ...
# 8                  Arduino  Arduino is an open source platform for buildin...
# 9                  ASP.NET  ASP.NET is a web framework for building modern...
# 10           Awesome Lists  An awesome list is a list of awesome things cu...
# 11     Amazon Web Services  Amazon Web Services provides on-demand cloud c...
# 12                   Azure  Azure is a cloud computing service created by ...
# 13                   Babel  Babel is a compiler for writing next generatio...
# 14                    Bash  Bash is a shell and command language interpret...
# 15                 Bitcoin  Bitcoin is a cryptocurrency developed by Satos...
# 16               Bootstrap  Bootstrap is an HTML, CSS, and JavaScript fram...
# 17                     Bot  A bot is an application that runs automated ta...
# 18                       C  C is a general purpose programming language th...
# 19                  Chrome  Chrome is a web browser from the tech company ...
# 20        Chrome extension  Chrome extensions enable users to customize th...
# 21  Command-line interface  A CLI, or command-line interface, is a console...
# 22                 Clojure  Clojure is a dynamic, general-purpose programm...
# 23            Code quality  Automate your code review with style, quality,...
# 24             Code review  Ensure your code meets quality standards and s...
# 25                Compiler  Compilers are software that translate higher-l...
# 26  Continuous integration  Automatically build and test your code as you ...
# 27                     C++  C++ is a general purpose and object-oriented p...
# 28          Cryptocurrency  A cryptocurrency is a digital currency that us...
# 29                 Crystal  Crystal is a self-hosted, general purpose prog...
#
#                                                  url
# 0                       https://github.com/topics/3d
# 1                     https://github.com/topics/ajax
# 2                https://github.com/topics/algorithm
# 3                    https://github.com/topics/amphp
# 4                  https://github.com/topics/android
# 5                  https://github.com/topics/angular
# 6                  https://github.com/topics/ansible
# 7                      https://github.com/topics/api
# 8                  https://github.com/topics/arduino
# 9                   https://github.com/topics/aspnet
# 10                 https://github.com/topics/awesome
# 11                     https://github.com/topics/aws
# 12                   https://github.com/topics/azure
# 13                   https://github.com/topics/babel
# 14                    https://github.com/topics/bash
# 15                 https://github.com/topics/bitcoin
# 16               https://github.com/topics/bootstrap
# 17                     https://github.com/topics/bot
# 18                       https://github.com/topics/c
# 19                  https://github.com/topics/chrome
# 20        https://github.com/topics/chrome-extension
# 21                     https://github.com/topics/cli
# 22                 https://github.com/topics/clojure
# 23            https://github.com/topics/code-quality
# 24             https://github.com/topics/code-review
# 25                https://github.com/topics/compiler
# 26  https://github.com/topics/continuous-integration
# 27                     https://github.com/topics/cpp
# 28          https://github.com/topics/cryptocurrency
# 29                 https://github.com/topics/crystal

# %%
topics_df = scrape_topics()

# %%
topics_df
# Out:
#                     titles                                              descs  \
# 0                       3D  3D refers to the use of three-dimensional grap...
# 1                     Ajax  Ajax is a technique for creating interactive w...
# 2                Algorithm  Algorithms are self-contained sequences that c...
# 3                      Amp  Amp is a non-blocking concurrency library for ...
# 4                  Android  Android is an operating system built by Google...
# 5                  Angular  Angular is an open source web application plat...
# 6                  Ansible  Ansible is a simple and powerful automation en...
# 7                      API  An API (Application Programming Interface) is ...
# 8                  Arduino  Arduino is an open source platform for buildin...
# 9                  ASP.NET  ASP.NET is a web framework for building modern...
# 10           Awesome Lists  An awesome list is a list of awesome things cu...
# 11     Amazon Web Services  Amazon Web Services provides on-demand cloud c...
# 12                   Azure  Azure is a cloud computing service created by ...
# 13                   Babel  Babel is a compiler for writing next generatio...
# 14                    Bash  Bash is a shell and command language interpret...
# 15                 Bitcoin  Bitcoin is a cryptocurrency developed by Satos...
# 16               Bootstrap  Bootstrap is an HTML, CSS, and JavaScript fram...
# 17                     Bot  A bot is an application that runs automated ta...
# 18                       C  C is a general purpose programming language th...
# 19                  Chrome  Chrome is a web browser from the tech company ...
# 20        Chrome extension  Chrome extensions enable users to customize th...
# 21  Command-line interface  A CLI, or command-line interface, is a console...
# 22                 Clojure  Clojure is a dynamic, general-purpose programm...
# 23            Code quality  Automate your code review with style, quality,...
# 24             Code review  Ensure your code meets quality standards and s...
# 25                Compiler  Compilers are software that translate higher-l...
# 26  Continuous integration  Automatically build and test your code as you ...
# 27                     C++  C++ is a general purpose and object-oriented p...
# 28          Cryptocurrency  A cryptocurrency is a digital currency that us...
# 29                 Crystal  Crystal is a self-hosted, general purpose prog...
#
#                                                  url
# 0                       https://github.com/topics/3d
# 1                     https://github.com/topics/ajax
# 2                https://github.com/topics/algorithm
# 3                    https://github.com/topics/amphp
# 4                  https://github.com/topics/android
# 5                  https://github.com/topics/angular
# 6                  https://github.com/topics/ansible
# 7                      https://github.com/topics/api
# 8                  https://github.com/topics/arduino
# 9                   https://github.com/topics/aspnet
# 10                 https://github.com/topics/awesome
# 11                     https://github.com/topics/aws
# 12                   https://github.com/topics/azure
# 13                   https://github.com/topics/babel
# 14                    https://github.com/topics/bash
# 15                 https://github.com/topics/bitcoin
# 16               https://github.com/topics/bootstrap
# 17                     https://github.com/topics/bot
# 18                       https://github.com/topics/c
# 19                  https://github.com/topics/chrome
# 20        https://github.com/topics/chrome-extension
# 21                     https://github.com/topics/cli
# 22                 https://github.com/topics/clojure
# 23            https://github.com/topics/code-quality
# 24             https://github.com/topics/code-review
# 25                https://github.com/topics/compiler
# 26  https://github.com/topics/continuous-integration
# 27                     https://github.com/topics/cpp
# 28          https://github.com/topics/cryptocurrency
# 29                 https://github.com/topics/crystal

# %%
for index,row in topics_df.iterrows():
    print(row['titles'],'=> ', row['url'])
# Out:
# 3D =>  https://github.com/topics/3d
# Ajax =>  https://github.com/topics/ajax
# Algorithm =>  https://github.com/topics/algorithm
# Amp =>  https://github.com/topics/amphp
# Android =>  https://github.com/topics/android
# Angular =>  https://github.com/topics/angular
# Ansible =>  https://github.com/topics/ansible
# API =>  https://github.com/topics/api
# Arduino =>  https://github.com/topics/arduino
# ASP.NET =>  https://github.com/topics/aspnet
# Awesome Lists =>  https://github.com/topics/awesome
# Amazon Web Services =>  https://github.com/topics/aws
# Azure =>  https://github.com/topics/azure
# Babel =>  https://github.com/topics/babel
# Bash =>  https://github.com/topics/bash
# Bitcoin =>  https://github.com/topics/bitcoin
# Bootstrap =>  https://github.com/topics/bootstrap
# Bot =>  https://github.com/topics/bot
# C =>  https://github.com/topics/c
# Chrome =>  https://github.com/topics/chrome
# Chrome extension =>  https://github.com/topics/chrome-extension
# Command-line interface =>  https://github.com/topics/cli
# Clojure =>  https://github.com/topics/clojure
# Code quality =>  https://github.com/topics/code-quality
# Code review =>  https://github.com/topics/code-review
# Compiler =>  https://github.com/topics/compiler
# Continuous integration =>  https://github.com/topics/continuous-integration
# C++ =>  https://github.com/topics/cpp
# Cryptocurrency =>  https://github.com/topics/cryptocurrency
# Crystal =>  https://github.com/topics/crystal

# %%
def scrape_topic_repos():
    print("Scarping starts: ")
    topics_df = scrape_topics()
    for index,row in topics_df.iterrows():
        print('Scraping top respos for "{}"'.format(row['titles']))
        scrape_topic(row['url'],row['titles'])

# %%
scrape_topic_repos()
# Out:
# Scarping starts:
# Scraping top respos for "3D"
# Scraping top respos for "Ajax"
# Scraping top respos for "Algorithm"
# Scraping top respos for "Amp"
# Scraping top respos for "Android"
# Scraping top respos for "Angular"
# Scraping top respos for "Ansible"
# Scraping top respos for "API"
# Scraping top respos for "Arduino"
# Scraping top respos for "ASP.NET"
# Scraping top respos for "Awesome Lists"
# Scraping top respos for "Amazon Web Services"
# Scraping top respos for "Azure"
# Scraping top respos for "Babel"
# Scraping top respos for "Bash"
# Scraping top respos for "Bitcoin"
# Scraping top respos for "Bootstrap"
# Scraping top respos for "Bot"
# Scraping top respos for "C"
# Scraping top respos for "Chrome"
# Scraping top respos for "Chrome extension"
# Scraping top respos for "Command-line interface"
# Scraping top respos for "Clojure"
# Scraping top respos for "Code quality"
# Scraping top respos for "Code review"
# Scraping top respos for "Compiler"
# Scraping top respos for "Continuous integration"
# Scraping top respos for "C++"
# Scraping top respos for "Cryptocurrency"
# Scraping top respos for "Crystal"

# %%
scrape_topic_repos()
# Out:
# Scarping starts:
# Scraping top respos for "3D"
# The file 3D.csv already exists
# Scraping top respos for "Ajax"
# The file Ajax.csv already exists
# Scraping top respos for "Algorithm"
# The file Algorithm.csv already exists
# Scraping top respos for "Amp"
# The file Amp.csv already exists
# Scraping top respos for "Android"
# The file Android.csv already exists
# Scraping top respos for "Angular"
# The file Angular.csv already exists
# Scraping top respos for "Ansible"
# The file Ansible.csv already exists
# Scraping top respos for "API"
# The file API.csv already exists
# Scraping top respos for "Arduino"
# The file Arduino.csv already exists
# Scraping top respos for "ASP.NET"
# The file ASP.NET.csv already exists
# Scraping top respos for "Awesome Lists"
# The file Awesome Lists.csv already exists
# Scraping top respos for "Amazon Web Services"
# The file Amazon Web Services.csv already exists
# Scraping top respos for "Azure"
# The file Azure.csv already exists
# Scraping top respos for "Babel"
# The file Babel.csv already exists
# Scraping top respos for "Bash"
# The file Bash.csv already exists
# Scraping top respos for "Bitcoin"
# The file Bitcoin.csv already exists
# Scraping top respos for "Bootstrap"
# The file Bootstrap.csv already exists
# Scraping top respos for "Bot"
# The file Bot.csv already exists
# Scraping top respos for "C"
# The file C.csv already exists
# Scraping top respos for "Chrome"
# The file Chrome.csv already exists
# Scraping top respos for "Chrome extension"
# The file Chrome extension.csv already exists
# Scraping top respos for "Command-line interface"
# The file Command-line interface.csv already exists
# Scraping top respos for "Clojure"
# The file Clojure.csv already exists
# Scraping top respos for "Code quality"
# The file Code quality.csv already exists
# Scraping top respos for "Code review"
# The file Code review.csv already exists
# Scraping top respos for "Compiler"
# The file Compiler.csv already exists
# Scraping top respos for "Continuous integration"
# The file Continuous integration.csv already exists
# Scraping top respos for "C++"
# The file C++.csv already exists
# Scraping top respos for "Cryptocurrency"
# The file Cryptocurrency.csv already exists
# Scraping top respos for "Crystal"
# The file Crystal.csv already exists
